# %% [markdown]
# #**I- La calculette avec gestion des erreurs**

# %%
# 1) Avec "try/except"

def test():
  try:
    chiffre1 = int(input("Rentrer un premier nombre : "))
    chiffre2 = int(input("Rentrer un deuxième nombre : "))
    cal = chiffre1 + chiffre2
    print("Le résultat du calcul est :", cal)
  except ValueError:
    print("Ce n'est pas un chiffre. Veuillez entrer un nombre entier.")
    return test()

test()

#2) Sans "try/except"

while True:
  chiffre1_input = input("Rentrer un premier nombre : ")
  chiffre2_input = input("Rentrer un deuxième nombre : ")

  if chiffre1_input.isdigit() and chiffre2_input.isdigit():
      chiffre1 = int(chiffre1_input)
      chiffre2 = int(chiffre2_input)
      cal = chiffre1 + chiffre2
      print("Le résultat du calcul est :", cal)
      break
  else:
      print("Ce n'est pas un chiffre. Veuillez entrer un nombre entier.")

# %% [markdown]
# #**I- La calculette V2 avec gestion des erreurs**

# %%
#Le bloc "try-except" spécifie le type d'erreur qu'on veut gérer
#dans le "except" en utilisant le nom de l'erreur dans la console.
#ici : ValueError
try:
#Le "int" permet de chager notre "str" en "int".
  nombre_a_gauche= int(input("Ecrire un nombre :"))
except ValueError:
      print("Ceci n'est pas un nombre")

operation = input("Choisir une opération : +, -, * ou / : ")
if operation not in ["+", "-", "*", "/"]:
  print("Ceci n'est pas un signe d'opération")

try:
  nombre_a_droite= int(input("Ecrire un deuxième nombre: "))
except ValueError:
  print("Ceci n'est pas un nombre")

resultat = 0

if operation == "+":
  resultat = nombre_a_gauche + nombre_a_droite
elif operation == "-":
  resultat = nombre_a_gauche - nombre_a_droite
elif operation == "*":
  resultat = nombre_a_gauche * nombre_a_droite
elif operation == "/":
  try:
    resultat = nombre_a_gauche / nombre_a_droite
#Ici l'erreur que l'on veut by-passer n'est pas "ValueErreur"
#mais "ZeroDivisionError"
  except ZeroDivisionError :
    print("Une division se divise pas par 0 :")
else :
  print("Error")

print(resultat)

# %% [markdown]
# #**II- La liste de course**

# %%
import sys # Permet de sortir du script avec la methode ".exit" ds le choix 5

menu = '''Choisissez parmis les 5 options suivantes :
1: A jouter un élèment à une liste
2: Retirer un élément à une liste
3: Afficher la liste
4: Vider la liste
5: Quitter
👉 Votre choix : '''

l = []
choix_menu = ["1", "2", "3", "4", "5"] #L'entrée utilisateur (input) est toujours "str", donc pour comparer il faut que ce soir un liste en "str".

while True:
  demande = input(menu)

  while demande not in choix_menu :
    print("Le choix n'est pas valide")
    demande = input(menu)

  if demande == "1" :
    ajout = input("Quel aliment voulez-vous ajouter :").lower()  #.lower() permet de tout mettre en minuscule pour comparer en minucule et pas se tromper
    l.append(ajout)

  elif demande == "2" :
    item = input("Quel élément voulez-vous retirer :").lower()
    if item in l :
      l.remove(item)
    else :
      print("L'élément n'est pas dans liste")

  elif demande == "3" :
    print("Voici la liste")
    print(l)

  elif demande == "4" :
    print("Liste effacée")
    l.clear()

  elif demande == "5" :
    print("A bientôt !")
    sys.exit() #Quite le programme

  print("-" * 50) #Sert de séparateur afin (on imprime 50 x "-")

# %% [markdown]
# #**III- Le nombre mystère**

# %%
print("🔷🔷🔷 Le jeu du mot mystère 🔷🔷🔷")
nbr = 31
essaie = 3

while demande != nbr:
  try :
    demande = int(input(f"Vous avez {essaie} essaie{'s' if essaie > 1 else ' '}. Devinez le nombre : ")) # Mettre le "s" qd essaie sont > 2. Attention mettre '' et non ""!
  except ValueError:
    print("Ce n'est pas un nombre !!")
    continue
  if demande == nbr :
    print("Vous avez trouvé !!!")
    break
  elif demande > nbr :
    print("Le chiffre est plus petit que", demande)
  elif demande < nbr :
    print("Le chiffre est plus grand que", demande)
  else :
    print("Vous avez perdu, le nombre était", nbr)
    break
  essaie = essaie - 1

#Ou

'''
  essaie = essaie - 1
else :
  print("Vous avez perdu, le nombre était", nbr)
  break
  '''

# %% [markdown]
# #**IV- Le jeu de rôle**

# %%
# Ma 1ere sans le "pass" tour mais avec le "if demande == "1" or "2""" (franchement pas mal voir mieux)
# Egallement, pas d'utilisation d'indice de liste "["1","2"]"

import random
hero = 10 #Sa vie
enemie = 10 #Sa vie
potion = 3 #Si on prend potion, on passe son tour
dommage_hero = random.randint(5, 15) #Choisi un chiffre random entre 5 et 10 pour le dommage du héro
dommage_en = random.randint(5, 10) # Idem dommage de l'ennemie

while hero >= 0 and enemie >= 0  : # La boucle avec "and" continue tant que les deux personnages sont en vie. Si l'un d'eux perd, la condition devient fausse et la boucle se termine alors que La boucle avec "or" continuera tant que l'une des conditions est vraie.
  demande = input("Voulez-vous attaquer ⚔️ (1) ou prendre une potion 🧪 (2) : ")

# Demande "1" attaque "enemie"
  if demande == "1":
    enemie = enemie - dommage_en
    print("Vous avez infligé", dommage_en, "points de dommage à l'enemie, il lui reste ",enemie, "points de vie")

# Si demande "2" prise de ption pour "hero"
  if demande == "2":
    if potion > 0 :
      vie_hero = random.randint(15, 50)
      hero = hero + vie_hero
      print("Vous avez reçu", vie_hero, "points de vie suplémentaire, vous avez maintenant", hero, "points de vie")

 # Que ce soir demande "1" ou "2", le héro se fait attaquer.
  if demande == "1" or "2":
    hero = hero - dommage_hero
    print("L'ennemie vous a infligé", dommage_hero, "points de dommage et il vous reste", hero, "points de vie")
  print("-" * 50)

  if hero < 0 :
    print("vous avez perdu !!")
  elif enemie < 0 :
    print("Vous avez gagné !!")
# Out:
# Voulez-vous attaquer ⚔️ (1) ou prendre une potion 🧪 (2) : 2
# Vous avez reçu 20 points de vie suplémentaire, vous avez maintenant 30 points de vie
# L'ennemie vous a infligé 5 points de dommage et il vous reste 25 points de vie
# --------------------------------------------------
# Voulez-vous attaquer ⚔️ (1) ou prendre une potion 🧪 (2) : 1
# Vous avez infligé 6 points de dommage à l'enemie, il lui reste  4 points de vie
# L'ennemie vous a infligé 5 points de dommage et il vous reste 20 points de vie
# --------------------------------------------------
# Voulez-vous attaquer ⚔️ (1) ou prendre une potion 🧪 (2) : 1
# Vous avez infligé 6 points de dommage à l'enemie, il lui reste  -2 points de vie
# L'ennemie vous a infligé 5 points de dommage et il vous reste 15 points de vie
# --------------------------------------------------
# Vous avez gagné !!

# %%
#Ma 2ème version (plus élégante)
import random

hero = 10 #Sa vie
enemie = 10 #Sa vie
potion = 3 #Si on prend potion, on passe son tour
dommage_hero = random.randint(5, 15) #Choisi un chiffre random entre 5 et 10 pour le dommage du héro
dommage_en = random.randint(5, 10) # Idem dommage de l'ennemie
choix = ["1", "2"]

while True :
# Demande input hors de la boucle pour initier + choix
  demande = input("Voulez-vous attaquer ⚔️ " + choix[0] + " ou prendre une potion 🧪 " + choix[1] + " : ")

# Demande input dans une boucle pour éviter erreur de input et que l'utilisateur rentre bien "1" ou "2"
  while demande not in choix:
    demande = input("Voulez-vous attaquer ⚔️ " + choix[0] + " ou prendre une potion 🧪 " + choix[1] + " : ")

# Demande "1" : Attaque sur l'ennemie
  if demande == choix[0]:
    hero = hero - dommage_hero
    print("L'ennemie vous a infligé", dommage_hero, "points de dommage et il vous reste", hero, "points de vie")
    if demande == choix[1]: # Si choix "2" on passe car si on prend potion, on attaque pas mais l'ennemie attaque qd même le hero
      pass
    enemie = enemie - dommage_en
    print("Vous avez infligé", dommage_en, "points de dommage à l'ennemie et il lui reste", enemie, "points de vie")

# Demande "2" : Prise de la potion : donne des points et seul l'ennemie attaque
  elif demande == choix[1]:
    if potion > 0 :
      vie_hero = random.randint(15, 50)
      hero = hero + vie_hero - dommage_hero
      print("Vous avez reçu", vie_hero, "points de vie et l'ennemie vous a infligé", dommage_hero, "points de dommage et il vous reste", hero, "points de vie")
      print("Il vous reste", potion, "potions")
    else :
      print("Vous n'avez plus de potion ! ")
      continue
  print("-" * 50)

# Sortie de la boucle si un des 2 joueurs à une vie < 0
  if hero <= 0 :
    print("vous avez perdu !!")
    break
  elif enemie <= 0 :
    print("Vous avez gagné !!")
    break

# %% [markdown]
# #**V- Les "class"**

# %%
# 1) Le lancé de dé : sans argument

import random

class De():

  def lance(self):
    de1 = random.randint(1,6)
    de2 = random.randint(1,6)
    return de1, de2

essaie1 = De()
print(essaie1.lance())
