# %%
# Principales fonctions d'agrégation pour .groupby() et .pivot_table() dans Pandas :


# 1) Descrition des colonnes

#agg : Pour appliquer plusieurs fonctions d'agrégation.
grouped = prets.groupby("identifiant").agg(['sum', 'mean'])

#describe : Pour obtenir des statistiques descriptives.
grouped = prets.groupby("identifiant").describe()

#size : Pour compter le nombre d'éléments par groupe (similaire à count, mais retourne une Series au lieu d'un DataFrame).
grouped = prets.groupby("identifiant").size()

#count : Pour compter le nombre d'éléments (déjà mentionné).
grouped = prets.groupby("identifiant").count()



# 2) Une valeurs précises

#first : Pour obtenir le premier élément.
grouped = prets.groupby("identifiant").first()

#last : Pour obtenir le dernier élément.
grouped = prets.groupby("identifiant").last()

#nth : Pour obtenir le n-ième élément.
grouped = prets.groupby("identifiant").nth(1)

#min : Pour obtenir la valeur minimale (déjà mentionné).
grouped = prets.groupby("identifiant").min()

#max : Pour obtenir la valeur maximale (déjà mentionné).
grouped = prets.groupby("identifiant").max()



# 3) Les calculs de valeurs

#median : Pour obtenir la médiane.
grouped = prets.groupby("identifiant").median()

#std : Pour obtenir l'écart type.
grouped = prets.groupby("identifiant").std()

#var : Pour obtenir la variance.
grouped = prets.groupby("identifiant").var()

#sum : Pour calculer la somme (déjà mentionné).
grouped = prets.groupby("identifiant").sum()

#mean : Pour calculer la moyenne (déjà mentionné).
grouped = prets.groupby("identifiant").mean()

#prod : Pour obtenir le produit des éléments.
grouped = prets.groupby("identifiant").prod()

'''
Ces fonctions d'agrégation vous permettent de résumer et d'analyser les données groupées selon différents critères et perspectives.
Vous pouvez les utiliser individuellement ou les combiner avec la méthode agg pour appliquer plusieurs fonctions d'agrégation en même temps.
'''

# 4) .agg() : appliquer plusieurs fonctions d'agrégation à différentes colonne.

grouped = prets.groupby("identifiant").agg({
                                      "remboursement": "sum",
                                      "taux_endettement": "mean",
                                      "cout_total": "sum",
                                      "benefices": "sum"})
